# %% [markdown]
# Importamos librerias

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import tensorflow_probability as tfp
from keras import backend as K
import matplotlib.pyplot as plt
import skimage
from skimage.metrics import structural_similarity as ssim
import time
import cv2
import scipy.stats as stats
import seaborn as sns
import scipy.io

# %%
# !git clone https://github.com/luismiguel13/Test-Dataset-III-Marine.git
# Out:
# Cloning into 'Test-Dataset-III-Marine'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 1.82 MiB | 3.22 MiB/s, done.

# %% [markdown]
# Funciones

# %%
msel = tf.keras.losses.MeanSquaredError()

lamb = 0.001 

def tffkdomain(input_tensor):
  input = input_tensor*2
  input -=1
  out = None
  for i in range(11):
    Temp = input[:,:,:,i,:]
    inpp = tf.cast(Temp, tf.complex64)
    spectrum = tf.math.abs( tf.signal.fftshift(tf.signal.fft2d(inpp[0,:,:,:])) )
    div = tf.math.divide(spectrum,tf.reduce_max(spectrum))
    if out is not None:          
      out = tf.concat([out, tf.expand_dims(div, -1)], axis=2)

    else:
      out = tf.expand_dims(div,-1) 
  out = tf.expand_dims(out,0) 
  return  out

def custom_loss_function(y_true, y_pred):
  mse = tf.keras.losses.MeanSquaredError()
  mse_value = mse(y_true, y_pred)
  fk_true = tffkdomain(y_true) 
  fk_pred = tffkdomain(y_pred)
  mse_fk = mse(fk_true, fk_pred)
  return tf.add(mse_value,(lamb*mse_fk))

def fk_train(y_true, y_pred):
  mse = tf.keras.losses.MeanSquaredError()
  fk_true = tffkdomain(y_true) 
  fk_pred = tffkdomain(y_pred)
  mse_fk = mse(fk_true, fk_pred)
  return lamb*mse_fk

def log10_(x):
  numerator = K.log(x)
  denominator = K.log(K.constant(10, dtype=numerator.dtype))
  return numerator / denominator

def PSNR_train(y_true, y_pred):
  max_pixel = 1
  return 10.0 * log10_(  (max_pixel) / msel(y_true,y_pred)   )

def PSNR(y_true, y_pred):
  max_pixel = y_true.max()
  return 10.0 * log10_(  (max_pixel) / msel(y_true,y_pred)   )

def mse(vref, vcmp):

    if np.iscomplexobj(vref) or np.iscomplexobj(vcmp):
        dtype = np.complex128
    else:
        dtype = np.float64
    r = np.asarray(vref, dtype=dtype).ravel()
    c = np.asarray(vcmp, dtype=dtype).ravel()
    return np.mean(np.abs(r - c)**2)

def snr(vref, vcmp):

    dv = np.var(vref)
    with np.errstate(divide='ignore'):
        rt = dv / mse(vref, vcmp)
    return 10.0 * np.log10(rt)

    
def ssim_train(y_true, y_pred):
  max_val = 1
  return tf.image.ssim(y_true, y_pred, max_val)

# %% [markdown]
# Cargamos datos

# %%
m2 = 128
n2 = 128
l1 = 16


x = np.load('/content/Test-Dataset-III-Marine/data_marine_16shots.npy')

t = x.shape
m1 = t[0]
n1 = t[1]
l1 = t[2]

shots_delete = [3,5,7,10,12]
shots_p = [0,1,2,4,6,8,9,11,13,14,15]
num_delete_shots = 5

y_train = np.ndarray((1,m2,n2,l1-num_delete_shots,1),dtype="float32")
for i in range(l1-num_delete_shots):
    y_train[0,:,:,i,0] = x[:,:,shots_p[i]]

# Repetir experimentos con la misma semilla
np.random.seed(0)
z_iter = np.random.rand(1,m2,n2,l1,1)
z_iter = np.float32(z_iter)

plt.imshow(z_iter[0,:,:,0,0],cmap='gray')
plt.show()

plt.imshow(y_train[0,:,:,10,0],cmap='gray')
plt.show()
z_iter = tf.convert_to_tensor(z_iter)
print(np.max(x),np.min(x))
# Out:
# 1.0 0.0

# %% [markdown]
# U-Net 3D

# %%
def model_unet(pretrained_weights=None,input_size=(m2,n2,l1,1),FLAGS=None):
  inputs=Input(input_size)

  n = 16
  kernel= 3
  fun_act = "sigmoid"
  kernel_i =  tf.keras.initializers.RandomUniform(minval=-0.05, maxval=0.05, seed=1)

  conv1 = Conv3D(n, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(inputs)
  bn1 = BatchNormalization()(conv1)
  relu1 = Activation(fun_act)(bn1)
  conv1 = Conv3D(n, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu1)
  bn1 = BatchNormalization()(conv1)
  relu1_sc = Activation(fun_act)(bn1)
  conv1 = Conv3D(n, kernel, strides=(2, 2, 2), padding="same", kernel_initializer=kernel_i)(relu1_sc)
  bn1 = BatchNormalization()(conv1)
  relu1 = Activation(fun_act)(bn1)

  conv2 = Conv3D(n*2, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu1)
  bn2 = BatchNormalization()(conv2)
  relu2 = Activation(fun_act)(bn2)
  conv2 = Conv3D(n*2, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu2)
  bn2 = BatchNormalization()(conv2)
  relu2_sc = Activation(fun_act)(bn2)
  conv2 = Conv3D(n*2, kernel_size = kernel, strides=(2, 2, 2), padding="same", kernel_initializer=kernel_i)(relu2_sc)
  bn2 = BatchNormalization()(conv2)
  relu2 = Activation(fun_act)(bn2)

  conv3 = Conv3D(n*4, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu2)
  bn3 = BatchNormalization()(conv3)
  relu3 = Activation(fun_act)(bn3)
  conv3 = Conv3D(n*4, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu3)
  bn3 = BatchNormalization()(conv3)
  relu3_sc = Activation(fun_act)(bn3)
  conv3 = Conv3D(n*4, kernel_size = kernel, strides=(2, 2, 2), padding="same", kernel_initializer=kernel_i)(relu3_sc)
  bn3 = BatchNormalization()(conv3)
  relu3 = Activation(fun_act)(bn3)

  conv4 = Conv3D(n*6, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu3)
  bn4 = BatchNormalization()(conv4)
  relu4 = Activation(fun_act)(bn4)
  conv4 = Conv3D(n*6, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu4)
  bn4 = BatchNormalization()(conv4)
  relu4_sc = Activation(fun_act)(bn4)
  conv4 = Conv3D(n*6, kernel_size = kernel, strides=(2, 2, 2), padding="same", kernel_initializer=kernel_i)(relu4_sc)
  bn4 = BatchNormalization()(conv4)
  relu4 = Activation(fun_act)(bn4)

  #middle
  conv5 = Conv3D(n*8, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu4)
  bn5 = BatchNormalization()(conv5)
  relu5 = Activation(fun_act)(bn5)
  conv5 = Conv3D(n*8, kernel_size = kernel, padding="same", kernel_initializer=kernel_i)(relu5)
  bn5 = BatchNormalization()(conv5)
  relu5 = Activation(fun_act)(bn5)
  up5 = UpSampling3D((2, 2, 2))(relu5)

  conv6 = Conv3D(n*6, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(up5)
  bn6 = BatchNormalization()(conv6)
  relu6 = Activation(fun_act)(bn6)
  sc6 = Add()([relu6, relu4_sc])
  conv6 = Conv3D(n*6, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(sc6)
  bn6 = BatchNormalization()(conv6)
  relu6 = Activation(fun_act)(bn6)
  conv6 = Conv3D(n*6, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(relu6)
  bn6 = BatchNormalization()(conv6)
  relu6 = Activation(fun_act)(bn6)
  up6 = UpSampling3D((2, 2, 2))(relu6)

  conv7 = Conv3D(n*4, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(up6)
  bn7 = BatchNormalization()(conv7)
  relu7 = Activation(fun_act)(bn7)
  sc7 = Add()([relu7, relu3_sc])
  conv7 = Conv3D(n*4, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(sc7)
  bn7 = BatchNormalization()(conv7)
  relu7 = Activation(fun_act)(bn7)
  conv7 = Conv3D(n*4, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(relu7)
  bn7 = BatchNormalization()(conv7)
  relu7 = Activation(fun_act)(bn7)
  up7 = UpSampling3D((2, 2, 2))(relu7)

  conv8 = Conv3D(n*2, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(up7)
  bn8 = BatchNormalization()(conv8)
  relu8 = Activation(fun_act)(bn8)
  sc8 = Add()([relu8, relu2_sc])
  conv8 = Conv3D(n*2, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(sc8)
  bn8 = BatchNormalization()(conv8)
  relu8 = Activation(fun_act)(bn8)
  conv8 = Conv3D(n*2, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(relu8)
  bn8 = BatchNormalization()(conv8)
  relu8 = Activation(fun_act)(bn8)
  up8 = UpSampling3D((2, 2, 2))(relu8)

  conv9 = Conv3D(n, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(up8)
  bn9 = BatchNormalization()(conv9)
  relu9 = Activation(fun_act)(bn9)
  sc9 = Add()([relu9, relu1_sc])
  conv9 = Conv3D(n, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(sc9)
  bn9 = BatchNormalization()(conv9)
  relu9 = Activation(fun_act)(bn9)
  conv9 = Conv3D(n, kernel_size = kernel,  padding="same", kernel_initializer=kernel_i)(relu9)
  bn9 = BatchNormalization()(conv9)
  relu9 = Activation(fun_act)(bn9)
  conv9 = Conv3D(1, kernel_size = 1,  padding="same", kernel_initializer=kernel_i)(relu9)
  bn9 = BatchNormalization()(conv9)
  relu9 = Activation('sigmoid')(bn9)

  output = Lambda(lambda x: tf.gather(x[0], x[1], axis=3))([relu9,shots_p])

  model = Model(inputs, output)

  if (pretrained_weights):
      model.load_weights(pretrained_weights)
  return model

unet = model_unet(input_size=(m2,n2,l1,1))
unet.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 6, 1)]
#
#  conv3d_162 (Conv3D)            (None, 128, 128, 16  448         ['input_7[0][0]']
#                                 , 16)
#
#  batch_normalization_162 (Batch  (None, 128, 128, 16  64         ['conv3d_162[0][0]']
#  Normalization)                 , 16)
#
#  activation_162 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_162[0][0]']
#                                 , 16)
#
#  conv3d_163 (Conv3D)            (None, 128, 128, 16  6928        ['activation_162[0][0]']
#                                 , 16)
#
#  batch_normalization_163 (Batch  (None, 128, 128, 16  64         ['conv3d_163[0][0]']
#  Normalization)                 , 16)
#
#  activation_163 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_163[0][0]']
#                                 , 16)
#
#  conv3d_164 (Conv3D)            (None, 64, 64, 8, 1  6928        ['activation_163[0][0]']
#                                 6)
#
#  batch_normalization_164 (Batch  (None, 64, 64, 8, 1  64         ['conv3d_164[0][0]']
#  Normalization)                 6)
#
#  activation_164 (Activation)    (None, 64, 64, 8, 1  0           ['batch_normalization_164[0][0]']
#                                 6)
#
#  conv3d_165 (Conv3D)            (None, 64, 64, 8, 3  13856       ['activation_164[0][0]']
#                                 2)
#
#  batch_normalization_165 (Batch  (None, 64, 64, 8, 3  128        ['conv3d_165[0][0]']
#  Normalization)                 2)
#
#  activation_165 (Activation)    (None, 64, 64, 8, 3  0           ['batch_normalization_165[0][0]']
#                                 2)
#
#  conv3d_166 (Conv3D)            (None, 64, 64, 8, 3  27680       ['activation_165[0][0]']
#                                 2)
#
#  batch_normalization_166 (Batch  (None, 64, 64, 8, 3  128        ['conv3d_166[0][0]']
#  Normalization)                 2)
#
#  activation_166 (Activation)    (None, 64, 64, 8, 3  0           ['batch_normalization_166[0][0]']
#                                 2)
#
#  conv3d_167 (Conv3D)            (None, 32, 32, 4, 3  27680       ['activation_166[0][0]']
#                                 2)
#
#  batch_normalization_167 (Batch  (None, 32, 32, 4, 3  128        ['conv3d_167[0][0]']
#  Normalization)                 2)
#
#  activation_167 (Activation)    (None, 32, 32, 4, 3  0           ['batch_normalization_167[0][0]']
#                                 2)
#
#  conv3d_168 (Conv3D)            (None, 32, 32, 4, 6  55360       ['activation_167[0][0]']
#                                 4)
#
#  batch_normalization_168 (Batch  (None, 32, 32, 4, 6  256        ['conv3d_168[0][0]']
#  Normalization)                 4)
#
#  activation_168 (Activation)    (None, 32, 32, 4, 6  0           ['batch_normalization_168[0][0]']
#                                 4)
#
#  conv3d_169 (Conv3D)            (None, 32, 32, 4, 6  110656      ['activation_168[0][0]']
#                                 4)
#
#  batch_normalization_169 (Batch  (None, 32, 32, 4, 6  256        ['conv3d_169[0][0]']
#  Normalization)                 4)
#
#  activation_169 (Activation)    (None, 32, 32, 4, 6  0           ['batch_normalization_169[0][0]']
#                                 4)
#
#  conv3d_170 (Conv3D)            (None, 16, 16, 2, 6  110656      ['activation_169[0][0]']
#                                 4)
#
#  batch_normalization_170 (Batch  (None, 16, 16, 2, 6  256        ['conv3d_170[0][0]']
#  Normalization)                 4)
#
#  activation_170 (Activation)    (None, 16, 16, 2, 6  0           ['batch_normalization_170[0][0]']
#                                 4)
#
#  conv3d_171 (Conv3D)            (None, 16, 16, 2, 9  165984      ['activation_170[0][0]']
#                                 6)
#
#  batch_normalization_171 (Batch  (None, 16, 16, 2, 9  384        ['conv3d_171[0][0]']
#  Normalization)                 6)
#
#  activation_171 (Activation)    (None, 16, 16, 2, 9  0           ['batch_normalization_171[0][0]']
#                                 6)
#
#  conv3d_172 (Conv3D)            (None, 16, 16, 2, 9  248928      ['activation_171[0][0]']
#                                 6)
#
#  batch_normalization_172 (Batch  (None, 16, 16, 2, 9  384        ['conv3d_172[0][0]']
#  Normalization)                 6)
#
#  activation_172 (Activation)    (None, 16, 16, 2, 9  0           ['batch_normalization_172[0][0]']
#                                 6)
#
#  conv3d_173 (Conv3D)            (None, 8, 8, 1, 96)  248928      ['activation_172[0][0]']
#
#  batch_normalization_173 (Batch  (None, 8, 8, 1, 96)  384        ['conv3d_173[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 8, 8, 1, 96)  0           ['batch_normalization_173[0][0]']
#
#  conv3d_174 (Conv3D)            (None, 8, 8, 1, 128  331904      ['activation_173[0][0]']
#                                 )
#
#  batch_normalization_174 (Batch  (None, 8, 8, 1, 128  512        ['conv3d_174[0][0]']
#  Normalization)                 )
#
#  activation_174 (Activation)    (None, 8, 8, 1, 128  0           ['batch_normalization_174[0][0]']
#                                 )
#
#  conv3d_175 (Conv3D)            (None, 8, 8, 1, 128  442496      ['activation_174[0][0]']
#                                 )
#
#  batch_normalization_175 (Batch  (None, 8, 8, 1, 128  512        ['conv3d_175[0][0]']
#  Normalization)                 )
#
#  activation_175 (Activation)    (None, 8, 8, 1, 128  0           ['batch_normalization_175[0][0]']
#                                 )
#
#  up_sampling3d_24 (UpSampling3D  (None, 16, 16, 2, 1  0          ['activation_175[0][0]']
#  )                              28)
#
#  conv3d_176 (Conv3D)            (None, 16, 16, 2, 9  331872      ['up_sampling3d_24[0][0]']
#                                 6)
#
#  batch_normalization_176 (Batch  (None, 16, 16, 2, 9  384        ['conv3d_176[0][0]']
#  Normalization)                 6)
#
#  activation_176 (Activation)    (None, 16, 16, 2, 9  0           ['batch_normalization_176[0][0]']
#                                 6)
#
#  add_24 (Add)                   (None, 16, 16, 2, 9  0           ['activation_176[0][0]',
#                                 6)                                'activation_172[0][0]']
#
#  conv3d_177 (Conv3D)            (None, 16, 16, 2, 9  248928      ['add_24[0][0]']
#                                 6)
#
#  batch_normalization_177 (Batch  (None, 16, 16, 2, 9  384        ['conv3d_177[0][0]']
#  Normalization)                 6)
#
#  activation_177 (Activation)    (None, 16, 16, 2, 9  0           ['batch_normalization_177[0][0]']
#                                 6)
#
#  conv3d_178 (Conv3D)            (None, 16, 16, 2, 9  248928      ['activation_177[0][0]']
#                                 6)
#
#  batch_normalization_178 (Batch  (None, 16, 16, 2, 9  384        ['conv3d_178[0][0]']
#  Normalization)                 6)
#
#  activation_178 (Activation)    (None, 16, 16, 2, 9  0           ['batch_normalization_178[0][0]']
#                                 6)
#
#  up_sampling3d_25 (UpSampling3D  (None, 32, 32, 4, 9  0          ['activation_178[0][0]']
#  )                              6)
#
#  conv3d_179 (Conv3D)            (None, 32, 32, 4, 6  165952      ['up_sampling3d_25[0][0]']
#                                 4)
#
#  batch_normalization_179 (Batch  (None, 32, 32, 4, 6  256        ['conv3d_179[0][0]']
#  Normalization)                 4)
#
#  activation_179 (Activation)    (None, 32, 32, 4, 6  0           ['batch_normalization_179[0][0]']
#                                 4)
#
#  add_25 (Add)                   (None, 32, 32, 4, 6  0           ['activation_179[0][0]',
#                                 4)                                'activation_169[0][0]']
#
#  conv3d_180 (Conv3D)            (None, 32, 32, 4, 6  110656      ['add_25[0][0]']
#                                 4)
#
#  batch_normalization_180 (Batch  (None, 32, 32, 4, 6  256        ['conv3d_180[0][0]']
#  Normalization)                 4)
#
#  activation_180 (Activation)    (None, 32, 32, 4, 6  0           ['batch_normalization_180[0][0]']
#                                 4)
#
#  conv3d_181 (Conv3D)            (None, 32, 32, 4, 6  110656      ['activation_180[0][0]']
#                                 4)
#
#  batch_normalization_181 (Batch  (None, 32, 32, 4, 6  256        ['conv3d_181[0][0]']
#  Normalization)                 4)
#
#  activation_181 (Activation)    (None, 32, 32, 4, 6  0           ['batch_normalization_181[0][0]']
#                                 4)
#
#  up_sampling3d_26 (UpSampling3D  (None, 64, 64, 8, 6  0          ['activation_181[0][0]']
#  )                              4)
#
#  conv3d_182 (Conv3D)            (None, 64, 64, 8, 3  55328       ['up_sampling3d_26[0][0]']
#                                 2)
#
#  batch_normalization_182 (Batch  (None, 64, 64, 8, 3  128        ['conv3d_182[0][0]']
#  Normalization)                 2)
#
#  activation_182 (Activation)    (None, 64, 64, 8, 3  0           ['batch_normalization_182[0][0]']
#                                 2)
#
#  add_26 (Add)                   (None, 64, 64, 8, 3  0           ['activation_182[0][0]',
#                                 2)                                'activation_166[0][0]']
#
#  conv3d_183 (Conv3D)            (None, 64, 64, 8, 3  27680       ['add_26[0][0]']
#                                 2)
#
#  batch_normalization_183 (Batch  (None, 64, 64, 8, 3  128        ['conv3d_183[0][0]']
#  Normalization)                 2)
#
#  activation_183 (Activation)    (None, 64, 64, 8, 3  0           ['batch_normalization_183[0][0]']
#                                 2)
#
#  conv3d_184 (Conv3D)            (None, 64, 64, 8, 3  27680       ['activation_183[0][0]']
#                                 2)
#
#  batch_normalization_184 (Batch  (None, 64, 64, 8, 3  128        ['conv3d_184[0][0]']
#  Normalization)                 2)
#
#  activation_184 (Activation)    (None, 64, 64, 8, 3  0           ['batch_normalization_184[0][0]']
#                                 2)
#
#  up_sampling3d_27 (UpSampling3D  (None, 128, 128, 16  0          ['activation_184[0][0]']
#  )                              , 32)
#
#  conv3d_185 (Conv3D)            (None, 128, 128, 16  13840       ['up_sampling3d_27[0][0]']
#                                 , 16)
#
#  batch_normalization_185 (Batch  (None, 128, 128, 16  64         ['conv3d_185[0][0]']
#  Normalization)                 , 16)
#
#  activation_185 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_185[0][0]']
#                                 , 16)
#
#  add_27 (Add)                   (None, 128, 128, 16  0           ['activation_185[0][0]',
#                                 , 16)                             'activation_163[0][0]']
#
#  conv3d_186 (Conv3D)            (None, 128, 128, 16  6928        ['add_27[0][0]']
#                                 , 16)
#
#  batch_normalization_186 (Batch  (None, 128, 128, 16  64         ['conv3d_186[0][0]']
#  Normalization)                 , 16)
#
#  activation_186 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_186[0][0]']
#                                 , 16)
#
#  conv3d_187 (Conv3D)            (None, 128, 128, 16  6928        ['activation_186[0][0]']
#                                 , 16)
#
#  batch_normalization_187 (Batch  (None, 128, 128, 16  64         ['conv3d_187[0][0]']
#  Normalization)                 , 16)
#
#  activation_187 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_187[0][0]']
#                                 , 16)
#
#  conv3d_188 (Conv3D)            (None, 128, 128, 16  17          ['activation_187[0][0]']
#                                 , 1)
#
#  batch_normalization_188 (Batch  (None, 128, 128, 16  4          ['conv3d_188[0][0]']
#  Normalization)                 , 1)
#
#  activation_188 (Activation)    (None, 128, 128, 16  0           ['batch_normalization_188[0][0]']
#                                 , 1)
#
#  lambda_6 (Lambda)              (None, 128, 128, 11  0           ['activation_188[0][0]']
#                                 , 1)
#
# ==================================================================================================
# Total params: 3,159,845
# Trainable params: 3,156,835
# Non-trainable params: 3,010
# __________________________________________________________________________________________________

# %%
num_test = 1
PSNR_list = []
SSIM_list = []
results = []

for j in range(num_test):
  print("Iter:",j+1)
  np.random.seed(0)
  z_iter = np.random.rand(1,m2,n2,l1,1)
  z_iter = np.float32(z_iter)
  z_iter = tf.convert_to_tensor(z_iter)

  learning_rate = 1e-3

  opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)

  unet = model_unet(input_size=(m2,n2,l1,1))
  unet.compile(optimizer=opt,loss=custom_loss_function,metrics=[PSNR_train,ssim_train,fk_train,msel])

  history = unet.fit(z_iter,y_train,epochs=3000,batch_size=1, verbose='auto')

  output = unet.layers[-2].output
  unet_pred = Model(inputs = unet.input, outputs = output)

  predict = unet_pred.predict(z_iter)
  x_reconstructed = np.array(tf.squeeze(predict))

  for i in range(num_delete_shots):
    print('     PSNR', PSNR(x[:,:,shots_delete[i]], x_reconstructed[:,:,shots_delete[i]]).numpy())
    print('     SSIM', ssim(x[:,:,shots_delete[i]],  x_reconstructed[:,:,shots_delete[i]]))
    SSIM_list.append(ssim(x[:,:,shots_delete[i]],  x_reconstructed[:,:,shots_delete[i]]))
    PSNR_list.append(PSNR(x[:,:,shots_delete[i]], x_reconstructed[:,:,shots_delete[i]]).numpy())

  results.append(x_reconstructed)

np.save('psnr_marine100', PSNR_list)
np.save('ssim_marine100.npy', SSIM_list)
np.save('x_marine100.npy', results)
